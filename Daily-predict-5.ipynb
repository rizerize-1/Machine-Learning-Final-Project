# %% [markdown]
# # **5 Day Weather Forecast**

# %% [markdown]
# ## 1. Setup

# %%
# 1. Setup & Imports
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import re
import os

import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import shap
from statsmodels.graphics.tsaplots import plot_acf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    mean_absolute_percentage_error,
    make_scorer,
    mean_squared_error,
    root_mean_squared_error,
    mean_absolute_error,
    r2_score
)
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.feature_selection import mutual_info_regression

from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor

import optuna
from optuna.samplers import TPESampler
from optuna.pruners import MedianPruner
from sklearn.ensemble import StackingRegressor

# %%
def rmse(y, yhat):
    return np.sqrt(mean_squared_error(y, yhat))

# %% [markdown]
# ## 2. Load local weather data

# %%
df = pd.read_excel("HCMWeatherDaily.xlsx")
df.head(5)
# Out:
#             name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  10.82, 106.67  2015-01-01     31.0     23.0  26.6          31.3
# 1  10.82, 106.67  2015-01-02     30.0     20.0  25.0          30.3
# 2  10.82, 106.67  2015-01-03     32.0     23.0  26.7          33.4
# 3  10.82, 106.67  2015-01-04     32.0     24.0  27.1          34.8
# 4  10.82, 106.67  2015-01-05     30.9     25.0  26.7          33.6
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          23.0       26.9  17.9      60.4  ...         19.9        8
# 1          20.0       25.1  15.7      56.7  ...         16.1        7
# 2          23.0       27.4  18.9      63.3  ...         16.0        8
# 3          24.0       28.3  21.2      71.3  ...         10.9        4
# 4          25.0       27.8  22.0      76.3  ...         14.1        8
#
#    severerisk              sunrise               sunset  moonphase  \
# 0         NaN  2015-01-01T06:11:34  2015-01-01T17:41:42       0.36
# 1         NaN  2015-01-02T06:11:58  2015-01-02T17:42:15       0.39
# 2         NaN  2015-01-03T06:12:21  2015-01-03T17:42:47       0.43
# 3         NaN  2015-01-04T06:12:44  2015-01-04T17:43:20       0.46
# 4         NaN  2015-01-05T06:13:05  2015-01-05T17:43:53       0.50
#
#                conditions                                        description  \
# 0        Partially cloudy                  Partly cloudy throughout the day.
# 1        Partially cloudy                  Partly cloudy throughout the day.
# 2  Rain, Partially cloudy  Partly cloudy throughout the day with rain in ...
# 3        Partially cloudy                  Partly cloudy throughout the day.
# 4  Rain, Partially cloudy  Partly cloudy throughout the day with morning ...
#
#                 icon                      stations
# 0  partly-cloudy-day  48894099999,48900099999,VVTS
# 1  partly-cloudy-day  48894099999,48900099999,VVTS
# 2               rain  48894099999,48900099999,VVTS
# 3  partly-cloudy-day  48894099999,48900099999,VVTS
# 4               rain  48894099999,48900099999,VVTS
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 3. Basic cleaning and encoding

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['sunrise'] = pd.to_datetime(df['sunrise'])
df['sunset'] = pd.to_datetime(df['sunset'])

df.drop(columns = ['name','snow','snowdepth','conditions','description','icon','stations','severerisk'], inplace = True)

# %%
# --- One-hot encode preciptype to has_rain (rain=1, NaN/others=0)
df['has_rain'] = (
    df['preciptype']
    .fillna('')          
    .str.lower()         
    .str.contains('rain')
    .astype(int)        
)

# Optional: drop the original column
df.drop(columns=['preciptype'], inplace=True)

# %%
# Precipitation (in → mm)
df['precip'] = df['precip'] * 25.4

# Percentage-based to fraction
pct_cols = ['humidity','cloudcover','precipprob','precipcover']
df[pct_cols] = df[pct_cols] / 100.0

# Wind (mph → m/s)
wind_cols = ['windspeed','windgust']
df[wind_cols] = df[wind_cols] / 2.237

# Visibility (mi → km)
df['visibility'] = df['visibility'] * 1.609

# Convert MJ/m²/day → W/m²-equivalent
df['solarenergy_wm2eq'] = df['solarenergy'] * 11.6

# %%
df['day_length'] = (
    (df['sunset'] - df['sunrise'])
    .dt.total_seconds()
    .div(3600)
    .clip(lower=0, upper=24)
)
df.drop(columns = ['sunrise','sunset'], inplace = True)

# %% [markdown]
# ## 4. Physics‑based feature engineering

# %%
# --- PHYSICS-BASED FEATURES (NO TEMP VARIABLES) ------------------------

# 1. Radiation efficiency — solar input vs cloud attenuation
df['radiation_efficiency'] = (
    (df['solarradiation'] + 0.1 * df['solarenergy'])
    / (df['cloudcover'].clip(lower=1) + 1e-3)
)
# assuming solarenergy is MJ/m2/day
df['rad_per_hour'] = df['solarenergy'] / (df['day_length'] + 1e-3)


# 2. Moisture ratio — dew point relative to humidity
df['dew_humidity_ratio'] = df['dew'] / df['humidity'].replace(0, np.nan)
df['dew_humidity_ratio'] = df['dew_humidity_ratio'].fillna(0)

# 3. Precipitation intensity — how concentrated rainfall is
df['precip_intensity'] = (
    df['precip'] / (df['precipcover'].replace(0, np.nan) + 1e-3)
).clip(upper=100)  # avoid division blow-ups

# 4. Wind components (convert polar → Cartesian)
df['wind_u'] = df['windspeed'] * np.cos(np.deg2rad(df['winddir']))
df['wind_v'] = df['windspeed'] * np.sin(np.deg2rad(df['winddir']))

# 5. Mean-centering to remove directional bias (optional for SHAP clarity)
df['wind_u'] -= df['wind_u'].mean()
df['wind_v'] -= df['wind_v'].mean()

# 6. Storminess index — dynamic proxy for convective activity
df['storminess'] = (df['windspeed'] ** 2) * (df['precipprob'] / 100.0)

# 7. Seasonal cycle — encode year-round periodicity
df['dayofyear'] = df['datetime'].dt.dayofyear
df['doy_sin'] = np.sin(2 * np.pi * df['dayofyear'] / 365.25)
df['doy_cos'] = np.cos(2 * np.pi * df['dayofyear'] / 365.25)

# %% [markdown]
# ## 5. Features engineering

# %%
windows = [3, 7, 14, 28, 56]
df = df.sort_values('datetime').reset_index(drop=True)

# ---------------------------------------------------------------
# 1️⃣  ROLLING /  LAGS
# ---------------------------------------------------------------
for w in [7, 28]:
    df[f'wind_u_mean_w{w}'] = df['wind_u'].rolling(w, 1).mean()
    df[f'wind_v_mean_w{w}'] = df['wind_v'].rolling(w, 1).mean()
    df[f'wind_u_var_w{w}']  = df['wind_u'].rolling(w, 1).var()
    df[f'wind_v_var_w{w}']  = df['wind_v'].rolling(w, 1).var()

# ---------------------------------------------------------------
# 2️⃣  PRESSURE & HUMIDITY GRADIENTS
# ---------------------------------------------------------------
df['pressure_change_1d'] = df['sealevelpressure'].diff(1)
df['humidity_change_1d'] = df['humidity'].diff(1)
df['dew_change_1d']      = df['dew'].diff(1)

for w in [7, 28]:
    df[f'pressure_mean_w{w}'] = df['sealevelpressure'].rolling(w,1).mean()
    df[f'pressure_var_w{w}']  = df['sealevelpressure'].rolling(w,1).var()
    df[f'humidity_mean_w{w}'] = df['humidity'].rolling(w,1).mean()
    df[f'humidity_var_w{w}']  = df['humidity'].rolling(w,1).var()

# ---------------------------------------------------------------
# 3️⃣  CLIMATE & REGIME INDICATORS
# ---------------------------------------------------------------
m = df['datetime'].dt.month
df['is_wet_season']   = m.isin([5,6,7,8,9,10]).astype(int)
df['season_progress'] = np.where(m < 5, 0, np.where(m > 10, 1, (m-5)/5.0))

wet14 = df['precip'].rolling(14,1).sum()
df['soil_wetness_index'] = 1 - np.exp(-0.05 * wet14)

df['sw_monsoon_flag'] = (df['wind_v'] > 0).astype(int)
df['ne_monsoon_flag'] = (df['wind_v'] < 0).astype(int)
df['wind_monsoon_index']     = 0.7*df['wind_u'] + 0.7*df['wind_v']
df['wind_monsoon_weighted']  = df['wind_monsoon_index'] * df.get('doy_sin',1.0)

# ---------------------------------------------------------------
# 4️⃣  LOW-NOISE CATEGORICAL PATTERNS
# ---------------------------------------------------------------
sea_sector = (df['winddir'] >= 90) & (df['winddir'] <= 210)
df['is_onshore_flow']  = sea_sector.astype(int)
df['is_offshore_flow'] = (~sea_sector).astype(int)

cloud7 = df['cloudcover'].rolling(7,1).mean()
df['cloudy_spell_flag'] = (cloud7 > 0.7).astype(int)
df['clear_spell_flag']  = (cloud7 < 0.3).astype(int)

df['precip_intensity'] = df['precip'] / (df['precipcover'] + 1e-3)
df.loc[df['precip']==0, 'precip_intensity'] = 0
med_intensity = df['precip_intensity'].median()
med_gust      = df['windgust'].median()
df['is_convective_rain'] = ((df['precip_intensity'] > med_intensity) &
                            (df['windgust'] > med_gust)).astype(int)
df['is_stratiform_rain'] = ((df['precip'] > 0) &
                            (df['is_convective_rain']==0)).astype(int)
df['convective_yesterday'] = df['is_convective_rain'].shift(1).fillna(0)

hum_thr = df['humidity'].median()
rad_thr = df['solarradiation'].median()
df['regime_hot_humid']    = ((df['humidity'] > hum_thr) & (df['solarradiation'] > rad_thr)).astype(int)
df['regime_hot_drier']    = ((df['humidity'] < hum_thr) & (df['solarradiation'] > rad_thr)).astype(int)
df['regime_cloudy_humid'] = ((df['humidity'] > hum_thr) & (df['solarradiation'] < rad_thr)).astype(int)

# ---------------------------------------------------------------
# 5️⃣  ADVANCED PHYSICAL-COHERENCE FEATURES (A–I)
# ---------------------------------------------------------------
u, v = df['wind_u'], df['wind_v']
df['wind_dir_consistency_w7']  = np.sqrt(u.rolling(7,1).mean()**2 + v.rolling(7,1).mean()**2) / (
                                  df['windspeed'].rolling(7,1).mean() + 1e-3)
df['wind_dir_consistency_w28'] = np.sqrt(u.rolling(28,1).mean()**2 + v.rolling(28,1).mean()**2) / (
                                  df['windspeed'].rolling(28,1).mean() + 1e-3)

df['wind_pressure_coupling'] = df['windspeed'] * (
    df['sealevelpressure'].rolling(3,1).mean() - df['sealevelpressure'].rolling(7,1).mean()
)

df['humid_radiation_balance'] = df['humidity'].rolling(3,1).mean() * df['solarradiation'].rolling(3,1).mean()
df['humid_radiation_ratio']   = df['humidity'] / (df['solarradiation'] + 1e-3)

if 'rain_risk_combo_w7' in df.columns:
    df['rain_risk_trend_3d'] = df['rain_risk_combo_w7'] - df['rain_risk_combo_w7'].shift(3)
    df['rain_risk_yesterday'] = df['rain_risk_combo_w7'].shift(1)
else:
    df['rain_risk_trend_3d'] = 0
    df['rain_risk_yesterday'] = 0

pairs = [('humidity','solarradiation'),
         ('wind_u','wind_v'),
         ('humidity','precip'),
         ('sealevelpressure','windspeed')]
for a,b in pairs:
    df[f'{a}_{b}_cov7'] = df[a].rolling(7,1).cov(df[b])

df['mean_wind_dir_w7']  = np.rad2deg(np.arctan2(df['wind_v_mean_w7'],  df['wind_u_mean_w7']))  % 360
df['mean_wind_dir_w28'] = np.rad2deg(np.arctan2(df['wind_v_mean_w28'], df['wind_u_mean_w28'])) % 360
df['mean_wind_dir_w7_rad']  = np.deg2rad(df['mean_wind_dir_w7'])
df['mean_wind_dir_w28_rad'] = np.deg2rad(df['mean_wind_dir_w28'])
df['mean_wind_dir_w7_sin']  = np.sin(df['mean_wind_dir_w7_rad'])
df['mean_wind_dir_w7_cos']  = np.cos(df['mean_wind_dir_w7_rad'])
df['mean_wind_dir_w28_sin'] = np.sin(df['mean_wind_dir_w28_rad'])
df['mean_wind_dir_w28_cos'] = np.cos(df['mean_wind_dir_w28_rad'])

bins = np.arange(-22.5, 382.5, 45)
labels = ['N','NE','E','SE','S','SW','W','NW']
df['wind_sector_w7_cat']  = pd.cut(df['mean_wind_dir_w7'],  bins=bins, labels=labels, ordered=False)
df['wind_sector_w28_cat'] = pd.cut(df['mean_wind_dir_w28'], bins=bins, labels=labels, ordered=False)

df['precip_efficiency'] = df['precip'].rolling(3,1).sum() / (df['cloudcover'].rolling(3,1).mean() + 1e-3)
df['wind_energy']      = 0.5 * (df['windspeed'] ** 2)
df['wind_energy_anom'] = df['wind_energy'] - df['wind_energy'].rolling(56,1).mean()
df['convective_potential_index'] = df['humidity'].rolling(7,1).mean() * df['solarradiation'].rolling(7,1).mean()

# ---------------------------------------------------------------
# 6️⃣  CLEANUP & ALIGNMENT
# ---------------------------------------------------------------
# Drop optional categorical sectors before training
cat_cols = [c for c in df.columns if c.endswith('_cat')]
df = df.drop(columns=cat_cols, errors='ignore')

# Fill NaN numerics
df = df.fillna(0).iloc[max(windows):].reset_index(drop=True)

print("Feature engineering complete.")
print("Total feature count:", len(df.columns))
# Out:
# Feature engineering complete.
# Total feature count: 94

# %%
# === EWMA enhancement on df (not on train/val/test yet) ===
ewma_features = ['humidity', 'dew', 'solarradiation', 'sealevelpressure',
                 'windspeed', 'precip']

ewma_configs = {
    '3d': 0.5,
    '7d': 0.3,
    '14d': 0.15
}

for col in ewma_features:
    for tag, alpha in ewma_configs.items():
        df[f'{col}_ewma_{tag}'] = df[col].ewm(alpha=alpha, adjust=False).mean()

print(" EWMA features added to df")
# Out:
#  EWMA features added to df

# %% [markdown]
# ## 6. Target and split

# %%
horizons = {"t1":1, "t2":2, "t3":3, "t4":4, "t5":5}

for name, h in horizons.items():
    df[f"target_{name}"] = df["temp"].shift(-h)

df = df.dropna(subset=[f"target_{h}" for h in horizons]).reset_index(drop=True)

print("\nMulti-horizon targets created. Shape:", df.shape)
# Out:
# Multi-horizon targets created. Shape: (3873, 117)

# %%
split_idx = int(len(df) * 0.8)
train = df.iloc[:split_idx].copy()
test  = df.iloc[split_idx:].copy()

exclude_cols = ['datetime', 'temp'] + [f"target_{h}" for h in horizons]
feature_cols = [c for c in df.columns if c not in exclude_cols]

X_train_full = train[feature_cols].copy()
X_test_full  = test[feature_cols].copy()

y_train_dict = {h: train[f"target_{h}"].copy() for h in horizons}
y_test_dict  = {h: test[f"target_{h}"].copy()  for h in horizons}

print(f"Train: {X_train_full.shape}, Test: {X_test_full.shape}")
# Out:
# Train: (3098, 110), Test: (775, 110)

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def climatology_pred(train_frame, test_frame, target_col):
    train_hour = pd.to_datetime(train_frame["datetime"]).dt.hour
    test_hour  = pd.to_datetime(test_frame["datetime"]).dt.hour
    
    climo_map = (
        train_frame.assign(h=train_hour)
        .groupby("h")[target_col].mean()
        .to_dict()
    )
    gmean = train_frame[target_col].mean()
    return np.array([climo_map.get(h, gmean) for h in test_hour])

baseline_metrics = {}

for h in horizons:
    y_train_h = y_train_dict[h]
    y_test_h  = y_test_dict[h]
    
    pers = test["temp"].values
    climo = climatology_pred(train.assign(target=y_train_h),
                             test.assign(target=y_test_h),
                             target_col="target")
    
    baseline_metrics[h] = {
        "RMSE_persistence": rmse(y_test_h, pers),
        "RMSE_climatology": rmse(y_test_h, climo)
    }

print("\nBaseline computation complete.")
# Out:
# Baseline computation complete.

# %%
drop_cols = ['feelslike','feelslikemax','feelslikemin','tempmax','tempmin']

X_train_base = X_train_full.drop(columns=[c for c in drop_cols if c in X_train_full.columns], errors='ignore')
X_test_base  = X_test_full.drop(columns=[c for c in drop_cols if c in X_test_full.columns],  errors='ignore')

print("\nBase features after removing leakage columns:", X_train_base.shape)


# =====================================================================
# Function: Feature Selection for ONE Horizon
#     (Same logic as your reference block — MI → XGB → family ranking)
# =====================================================================
def select_features_like_reference(X_tr, y_tr, X_te,
                                   mi_pct=25,    # top 25% MI
                                   top_families=15,
                                   max_features=95):

    # ---------------------------------------------------------------
    # 1️⃣ Mutual Information (top 25%)
    # ---------------------------------------------------------------
    mi = mutual_info_regression(X_tr, y_tr, random_state=42)
    mi_s = pd.Series(mi, index=X_tr.columns).sort_values(ascending=False)

    cut = np.percentile(mi_s, 100 - mi_pct)
    top_feats = mi_s[mi_s > cut].index

    X_tr_fs = X_tr[top_feats]
    X_te_fs = X_te[top_feats]

    print(f"  MI → kept {len(top_feats)} features")

    # ---------------------------------------------------------------
    # 2️⃣ Lightweight XGB Importance
    # ---------------------------------------------------------------
    xgb_temp = XGBRegressor(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=None,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_lambda=3,
        reg_alpha=1,
        min_child_weight=5,
        random_state=42,
        n_jobs=-1,
        eval_metric='rmse'
    )
    xgb_temp.fit(X_tr_fs, y_tr)

    imp = pd.Series(
        xgb_temp.feature_importances_,
        index=X_tr_fs.columns
    ).sort_values(ascending=False)

    # ---------------------------------------------------------------
    # 3️⃣ Group importance by feature "family" prefix
    # ---------------------------------------------------------------
    def base(c):
        m = re.match(r'([A-Za-z_]+)_', c)
        return m.group(1) if m else c

    grp = imp.groupby(imp.index.map(base)).mean().sort_values(ascending=False)

    # ---------------------------------------------------------------
    # 4️⃣ Select top N families and up to max_features
    # ---------------------------------------------------------------
    families = grp.head(top_families).index

    sel = [f for f in imp.index if base(f) in families][:max_features]

    X_tr_sel = X_tr_fs[sel]
    X_te_sel = X_te_fs[sel]

    print(f"  Final selected features: {len(sel)}")

    # ---------------------------------------------------------------
    # 5️⃣ Retrain lightweight XGB on final subset (as in your reference)
    # ---------------------------------------------------------------
    xgb_temp.fit(X_tr_sel, y_tr)

    return X_tr_sel, X_te_sel, sel


X_train_sel_dict = {}
X_test_sel_dict  = {}
selected_features_dict = {}

for h in horizons:
    print(f"\n================ FEATURE SELECTION FOR {h} ================")

    Xtr = X_train_base.copy()
    Xte = X_test_base.copy()
    ytr = y_train_dict[h]

    X_tr_sel, X_te_sel, sel = select_features_like_reference(Xtr, ytr, Xte)

    X_train_sel_dict[h] = X_tr_sel
    X_test_sel_dict[h]  = X_te_sel
    selected_features_dict[h] = sel

    print(f"✔ Horizon {h}: {len(sel)} features")
# Out:
# Base features after removing leakage columns: (3098, 105)
#
# ================ FEATURE SELECTION FOR t1 ================
#   MI → kept 26 features
#   Final selected features: 25
# ✔ Horizon t1: 25 features
#
# ================ FEATURE SELECTION FOR t2 ================
#   MI → kept 26 features
#   Final selected features: 26
# ✔ Horizon t2: 26 features
#
# ================ FEATURE SELECTION FOR t3 ================
#   MI → kept 26 features
#   Final selected features: 26
# ✔ Horizon t3: 26 features
#
# ================ FEATURE SELECTION FOR t4 ================
#   MI → kept 26 features
#   Final selected features: 24
# ✔ Horizon t4: 24 features
#
# ================ FEATURE SELECTION FOR t5 ================
#   MI → kept 26 features
#   Final selected features: 26
# ✔ Horizon t5: 26 features

# %%
tscv = TimeSeriesSplit(n_splits=5)

def rmse_metric(y_true, y_pred):
    return rmse(y_true, y_pred)

scorer = make_scorer(lambda yt, yp: -rmse_metric(yt, yp), greater_is_better=True)

# %%
rf_best_params   = {}
xgb_best_params  = {}
lgbm_best_params = {}

for h in horizons:
    y_train_h = y_train_dict[h]
    X_h = X_train_sel_dict[h]

    print(f"\n🔍 OPTIMIZING HORIZON {h}")

    # RF
    def objective_rf(trial):
        params = {
            "n_estimators": trial.suggest_int("n_estimators", 100, 400, step=50),
            "max_depth": trial.suggest_int("max_depth", 4, 8),
            "min_samples_split": trial.suggest_int("min_samples_split", 5, 20),
            "min_samples_leaf": trial.suggest_int("min_samples_leaf", 3, 10),
            "max_features": trial.suggest_categorical("max_features", ["sqrt", 0.3, 0.5]),
            "random_state": 42,
            "n_jobs": -1
        }
        model = RandomForestRegressor(**params)
        scores = cross_val_score(model, X_h, y_train_h, cv=tscv, scoring=scorer, n_jobs=-1)
        return np.mean(scores)

    study_rf = optuna.create_study(direction="maximize", sampler=TPESampler(seed=42))
    study_rf.optimize(objective_rf, n_trials=30)
    rf_best_params[h] = study_rf.best_params

    # XGB
    def objective_xgb(trial):
        params = {
            "n_estimators": trial.suggest_int("n_estimators", 200, 600, step=100),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
            "max_depth": trial.suggest_int("max_depth", 3, 8),
            "min_child_weight": trial.suggest_int("min_child_weight", 1, 7),
            "subsample": trial.suggest_float("subsample", 0.6, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
            "reg_lambda": trial.suggest_float("reg_lambda", 1.0, 10.0),
            "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 2.0),
            "random_state": 42,
            "n_jobs": -1,
            "objective": "reg:squarederror"
        }
        model = XGBRegressor(**params)
        scores = cross_val_score(model, X_h, y_train_h, cv=tscv, scoring=scorer, n_jobs=-1)
        return np.mean(scores)

    study_xgb = optuna.create_study(direction="maximize", sampler=TPESampler(seed=42))
    study_xgb.optimize(objective_xgb, n_trials=30)
    xgb_best_params[h] = study_xgb.best_params

    # LGBM
    def objective_lgbm(trial):
        params = {
            "n_estimators": trial.suggest_int("n_estimators", 300, 700, step=100),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
            "num_leaves": trial.suggest_int("num_leaves", 20, 80),
            "max_depth": trial.suggest_int("max_depth", -1, 10),
            "subsample": trial.suggest_float("subsample", 0.6, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
            "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 5.0),
            "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 2.0),
            "min_child_samples": trial.suggest_int("min_child_samples", 5, 40),
            "random_state": 42,
            "n_jobs": -1
        }
        model = LGBMRegressor(**params)
        scores = cross_val_score(model, X_h, y_train_h, cv=tscv, scoring=scorer, n_jobs=-1)
        return np.mean(scores)

    study_lgbm = optuna.create_study(direction="maximize", sampler=TPESampler(seed=42))
    study_lgbm.optimize(objective_lgbm, n_trials=30)
    lgbm_best_params[h] = study_lgbm.best_params

print("\n Hyperparameter tuning complete.")
# Out:
# [I 2025-11-16 23:33:12,800] A new study created in memory with name: no-name-8a585ed1-48c6-448e-bb43-93875210333d
# 🔍 OPTIMIZING HORIZON t1
# [I 2025-11-16 23:33:22,815] Trial 0 finished with value: -0.881829015657668 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: -0.881829015657668.
# [I 2025-11-16 23:33:31,596] Trial 1 finished with value: -0.8793071927515715 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 1 with value: -0.8793071927515715.
# [I 2025-11-16 23:33:33,182] Trial 2 finished with value: -0.8785400519894029 and parameters: {'n_estimators': 150, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 0.5}. Best is trial 2 with value: -0.8785400519894029.
# [I 2025-11-16 23:33:33,918] Trial 3 finished with value: -0.9009140406162548 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 2 with value: -0.8785400519894029.
# [I 2025-11-16 23:33:37,373] Trial 4 finished with value: -0.8778428179679155 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.5}. Best is trial 4 with value: -0.8778428179679155.
# [I 2025-11-16 23:33:42,291] Trial 5 finished with value: -0.8627770340830254 and parameters: {'n_estimators': 350, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 5 with value: -0.8627770340830254.
# [I 2025-11-16 23:33:44,206] Trial 6 finished with value: -0.852725021847846 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 6 with value: -0.852725021847846.
# [I 2025-11-16 23:33:46,909] Trial 7 finished with value: -0.8517564531508659 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 0.5}. Best is trial 7 with value: -0.8517564531508659.
# [I 2025-11-16 23:33:48,061] Trial 8 finished with value: -0.8788529091960253 and parameters: {'n_estimators': 100, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 0.5}. Best is trial 7 with value: -0.8517564531508659.
# [I 2025-11-16 23:33:50,916] Trial 9 finished with value: -0.8624093248396842 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': 0.5}. Best is trial 7 with value: -0.8517564531508659.
# [I 2025-11-16 23:33:54,846] Trial 10 finished with value: -0.8691302331382434 and parameters: {'n_estimators': 250, 'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.3}. Best is trial 7 with value: -0.8517564531508659.
# [I 2025-11-16 23:33:56,955] Trial 11 finished with value: -0.8691171309478225 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.3}. Best is trial 7 with value: -0.8517564531508659.
# [I 2025-11-16 23:33:58,506] Trial 12 finished with value: -0.8552259999210203 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 7 with value: -0.8517564531508659.
# [I 2025-11-16 23:34:00,856] Trial 13 finished with value: -0.8502536479874123 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:03,488] Trial 14 finished with value: -0.8563794567189411 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:05,925] Trial 15 finished with value: -0.8691302331382434 and parameters: {'n_estimators': 250, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 0.3}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:07,968] Trial 16 finished with value: -0.8502536479874123 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:11,495] Trial 17 finished with value: -0.8544321900185883 and parameters: {'n_estimators': 300, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:12,600] Trial 18 finished with value: -0.8847937530703163 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:14,772] Trial 19 finished with value: -0.8640324008558796 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 0.3}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:18,494] Trial 20 finished with value: -0.8544321900185883 and parameters: {'n_estimators': 300, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:20,646] Trial 21 finished with value: -0.8502536479874123 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:22,624] Trial 22 finished with value: -0.8514913026118347 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:25,211] Trial 23 finished with value: -0.8509964417040026 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:27,044] Trial 24 finished with value: -0.8506344765307908 and parameters: {'n_estimators': 150, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:28,433] Trial 25 finished with value: -0.8516157036707561 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:31,466] Trial 26 finished with value: -0.8531305383488277 and parameters: {'n_estimators': 250, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:33,929] Trial 27 finished with value: -0.8521992758077841 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': 0.5}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:34,973] Trial 28 finished with value: -0.8858537094928256 and parameters: {'n_estimators': 150, 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:35,850] Trial 29 finished with value: -0.8639552591950089 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 0.3}. Best is trial 13 with value: -0.8502536479874123.
# [I 2025-11-16 23:34:35,860] A new study created in memory with name: no-name-2ccea518-86cb-4441-a7e5-a0ba96887699
# [I 2025-11-16 23:34:39,443] Trial 0 finished with value: -0.9093260820251604 and parameters: {'n_estimators': 300, 'learning_rate': 0.08927180304353628, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'reg_lambda': 1.5227525095137953, 'reg_alpha': 1.7323522915498704}. Best is trial 0 with value: -0.9093260820251604.
# [I 2025-11-16 23:34:40,407] Trial 1 finished with value: -0.8541375766102828 and parameters: {'n_estimators': 500, 'learning_rate': 0.051059032093947576, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'reg_lambda': 2.636424704863906, 'reg_alpha': 0.36680901970686763}. Best is trial 1 with value: -0.8541375766102828.
# [I 2025-11-16 23:34:41,832] Trial 2 finished with value: -0.8597238605494277 and parameters: {'n_estimators': 300, 'learning_rate': 0.03347776308515933, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8447411578889518, 'colsample_bytree': 0.6557975442608167, 'reg_lambda': 3.629301836816963, 'reg_alpha': 0.7327236865873834}. Best is trial 1 with value: -0.8541375766102828.
# [I 2025-11-16 23:34:42,935] Trial 3 finished with value: -0.8737406799079597 and parameters: {'n_estimators': 400, 'learning_rate': 0.06097839109531514, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.836965827544817, 'colsample_bytree': 0.6185801650879991, 'reg_lambda': 6.467903667112945, 'reg_alpha': 0.34104824737458306}. Best is trial 1 with value: -0.8541375766102828.
# [I 2025-11-16 23:34:45,081] Trial 4 finished with value: -0.8908950840267188 and parameters: {'n_estimators': 200, 'learning_rate': 0.08889667907018929, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.7218455076693483, 'colsample_bytree': 0.6390688456025535, 'reg_lambda': 7.158097238609412, 'reg_alpha': 0.8803049874792026}. Best is trial 1 with value: -0.8541375766102828.
# [I 2025-11-16 23:34:45,432] Trial 5 finished with value: -0.837189976984377 and parameters: {'n_estimators': 200, 'learning_rate': 0.03127353036780371, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'reg_lambda': 3.8053996848046987, 'reg_alpha': 1.0401360423556216}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:51,215] Trial 6 finished with value: -0.8750250840899886 and parameters: {'n_estimators': 400, 'learning_rate': 0.015305744365500184, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.9757995766256756, 'colsample_bytree': 0.9579309401710595, 'reg_lambda': 6.381099809299767, 'reg_alpha': 1.8437484700462337}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:51,515] Trial 7 finished with value: -0.8693661873206832 and parameters: {'n_estimators': 200, 'learning_rate': 0.015703008378806716, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.7554709158757928, 'colsample_bytree': 0.7085396127095583, 'reg_lambda': 8.458637582367365, 'reg_alpha': 0.7135066533871786}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:52,063] Trial 8 finished with value: -0.8395373609128116 and parameters: {'n_estimators': 300, 'learning_rate': 0.03488960745139221, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.6298202574719083, 'colsample_bytree': 0.9947547746402069, 'reg_lambda': 7.9502029236699165, 'reg_alpha': 0.3974313630683448}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:53,617] Trial 9 finished with value: -0.8819121101993563 and parameters: {'n_estimators': 200, 'learning_rate': 0.06538248584518043, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.9085081386743783, 'colsample_bytree': 0.6296178606936361, 'reg_lambda': 4.226191556898454, 'reg_alpha': 0.23173811905025943}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:56,779] Trial 10 finished with value: -0.8574561190486051 and parameters: {'n_estimators': 600, 'learning_rate': 0.010139048090380883, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.7090747508804338, 'colsample_bytree': 0.876098829427658, 'reg_lambda': 9.637936713508779, 'reg_alpha': 1.3531447594855595}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:57,584] Trial 11 finished with value: -0.8463631537529256 and parameters: {'n_estimators': 300, 'learning_rate': 0.02999641032856793, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.6133578302780329, 'colsample_bytree': 0.9938927369971033, 'reg_lambda': 4.59292636148357, 'reg_alpha': 1.2390678862671982}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:58,157] Trial 12 finished with value: -0.8406612233025118 and parameters: {'n_estimators': 300, 'learning_rate': 0.03171980772978617, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6290740943872529, 'colsample_bytree': 0.8547641978142754, 'reg_lambda': 8.005630538517243, 'reg_alpha': 1.1618575314902664}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:58,702] Trial 13 finished with value: -0.8473518669401956 and parameters: {'n_estimators': 200, 'learning_rate': 0.022964088725589093, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6750130525733469, 'colsample_bytree': 0.7826173426603852, 'reg_lambda': 5.724834452565788, 'reg_alpha': 0.010466103836478502}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:34:59,256] Trial 14 finished with value: -0.8459234114747476 and parameters: {'n_estimators': 300, 'learning_rate': 0.04250431472380467, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.7935877653929082, 'colsample_bytree': 0.9198691394873616, 'reg_lambda': 9.895466318667633, 'reg_alpha': 1.4892857096736558}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:02,005] Trial 15 finished with value: -0.864024132087868 and parameters: {'n_estimators': 500, 'learning_rate': 0.022114965417738976, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.6659938493420553, 'colsample_bytree': 0.7787529911389602, 'reg_lambda': 2.7504851643780444, 'reg_alpha': 0.5758185989301284}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:02,610] Trial 16 finished with value: -0.8496807788033738 and parameters: {'n_estimators': 200, 'learning_rate': 0.04099283010139801, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.6031679116388441, 'colsample_bytree': 0.8448620015652946, 'reg_lambda': 5.105039280577289, 'reg_alpha': 0.869849999965647}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:04,493] Trial 17 finished with value: -0.8539680696347716 and parameters: {'n_estimators': 400, 'learning_rate': 0.022589363652929576, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.7508012840516692, 'colsample_bytree': 0.929610159570076, 'reg_lambda': 1.1186129294283118, 'reg_alpha': 1.5562091456273734}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:06,679] Trial 18 finished with value: -0.869590869390402 and parameters: {'n_estimators': 300, 'learning_rate': 0.01749499042968468, 'max_depth': 6, 'min_child_weight': 2, 'subsample': 0.6904315777905318, 'colsample_bytree': 0.7281358941031667, 'reg_lambda': 8.55868180620948, 'reg_alpha': 0.5374795494285061}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:07,407] Trial 19 finished with value: -0.8495245692013851 and parameters: {'n_estimators': 400, 'learning_rate': 0.046536364192714605, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6439583097947424, 'colsample_bytree': 0.9859766250201053, 'reg_lambda': 7.529886697259929, 'reg_alpha': 1.032529775154952}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:08,722] Trial 20 finished with value: -0.851680490883614 and parameters: {'n_estimators': 500, 'learning_rate': 0.02768675361172045, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.745273591134237, 'colsample_bytree': 0.8978849513757344, 'reg_lambda': 3.373513077457167, 'reg_alpha': 0.05618944039931234}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:09,279] Trial 21 finished with value: -0.8434709760188263 and parameters: {'n_estimators': 300, 'learning_rate': 0.03538274233995562, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6297490068095127, 'colsample_bytree': 0.8407769474852015, 'reg_lambda': 8.288433347963085, 'reg_alpha': 1.081913359281376}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:09,790] Trial 22 finished with value: -0.8433900729989509 and parameters: {'n_estimators': 300, 'learning_rate': 0.026880357315209876, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6372206838044818, 'colsample_bytree': 0.8240195996363628, 'reg_lambda': 7.480763108235033, 'reg_alpha': 1.203579437656462}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:10,349] Trial 23 finished with value: -0.8495191710399075 and parameters: {'n_estimators': 200, 'learning_rate': 0.036889199705545016, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.710256683067927, 'colsample_bytree': 0.8749053156654778, 'reg_lambda': 9.175977484076261, 'reg_alpha': 0.9083043095954992}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:10,923] Trial 24 finished with value: -0.8416169452401897 and parameters: {'n_estimators': 300, 'learning_rate': 0.01888945595080922, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.61044924391467, 'colsample_bytree': 0.7631153485730923, 'reg_lambda': 5.952567918749059, 'reg_alpha': 1.3668042133442735}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:11,329] Trial 25 finished with value: -0.8424284239954369 and parameters: {'n_estimators': 200, 'learning_rate': 0.05543026087844717, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.7844707023078049, 'colsample_bytree': 0.9488760305359784, 'reg_lambda': 6.911962395534337, 'reg_alpha': 1.9988269881753706}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:12,090] Trial 26 finished with value: -0.8683773267460859 and parameters: {'n_estimators': 300, 'learning_rate': 0.07239394324188295, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.6466892477878086, 'colsample_bytree': 0.821869389826675, 'reg_lambda': 7.852360047803241, 'reg_alpha': 1.1620526242539342}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:12,968] Trial 27 finished with value: -0.851637804527785 and parameters: {'n_estimators': 200, 'learning_rate': 0.027666333642517395, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6960571958355273, 'colsample_bytree': 0.8680365598637271, 'reg_lambda': 5.0579669960566624, 'reg_alpha': 0.7058553361179167}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:13,637] Trial 28 finished with value: -0.8451120051800999 and parameters: {'n_estimators': 400, 'learning_rate': 0.039959660617411526, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.6750488568208661, 'colsample_bytree': 0.9061627492589288, 'reg_lambda': 9.000078127640185, 'reg_alpha': 0.9420881528894253}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:16,499] Trial 29 finished with value: -0.8697629467711602 and parameters: {'n_estimators': 300, 'learning_rate': 0.012442353132260447, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.7307471599718224, 'colsample_bytree': 0.7488621218277183, 'reg_lambda': 2.483435830357906, 'reg_alpha': 1.4802978111887035}. Best is trial 5 with value: -0.837189976984377.
# [I 2025-11-16 23:35:16,500] A new study created in memory with name: no-name-52e9514c-a45b-4c91-a4fb-1019648bf97a
# [I 2025-11-16 23:35:18,743] Trial 0 finished with value: -0.8978953646373398 and parameters: {'n_estimators': 400, 'learning_rate': 0.08927180304353628, 'num_leaves': 64, 'max_depth': 6, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'reg_lambda': 0.2904180608409973, 'reg_alpha': 1.7323522915498704, 'min_child_samples': 26}. Best is trial 0 with value: -0.8978953646373398.
# [I 2025-11-16 23:35:22,969] Trial 1 finished with value: -0.8616466483677675 and parameters: {'n_estimators': 600, 'learning_rate': 0.010485387725194618, 'num_leaves': 79, 'max_depth': 8, 'subsample': 0.6849356442713105, 'colsample_bytree': 0.6727299868828402, 'reg_lambda': 0.9170225492671691, 'reg_alpha': 0.6084844859190754, 'min_child_samples': 23}. Best is trial 1 with value: -0.8616466483677675.
# [I 2025-11-16 23:35:28,849] Trial 2 finished with value: -0.8749779184156761 and parameters: {'n_estimators': 500, 'learning_rate': 0.019553708662745254, 'num_leaves': 57, 'max_depth': 0, 'subsample': 0.7168578594140873, 'colsample_bytree': 0.7465447373174767, 'reg_lambda': 2.28034992108518, 'reg_alpha': 1.5703519227860272, 'min_child_samples': 12}. Best is trial 1 with value: -0.8616466483677675.
# [I 2025-11-16 23:35:30,629] Trial 3 finished with value: -0.8659999538666232 and parameters: {'n_estimators': 500, 'learning_rate': 0.03912141628549695, 'num_leaves': 22, 'max_depth': 6, 'subsample': 0.6682096494749166, 'colsample_bytree': 0.6260206371941118, 'reg_lambda': 4.7444276862666666, 'reg_alpha': 1.9312640661491187, 'min_child_samples': 34}. Best is trial 1 with value: -0.8616466483677675.
# [I 2025-11-16 23:35:31,817] Trial 4 finished with value: -0.8419053911768698 and parameters: {'n_estimators': 400, 'learning_rate': 0.012521954287060391, 'num_leaves': 61, 'max_depth': 4, 'subsample': 0.6488152939379115, 'colsample_bytree': 0.798070764044508, 'reg_lambda': 0.17194260557609198, 'reg_alpha': 1.8186408041575641, 'min_child_samples': 14}. Best is trial 4 with value: -0.8419053911768698.
# [I 2025-11-16 23:35:33,962] Trial 5 finished with value: -0.851082916568598 and parameters: {'n_estimators': 600, 'learning_rate': 0.020497980520950188, 'num_leaves': 51, 'max_depth': 5, 'subsample': 0.6739417822102108, 'colsample_bytree': 0.9878338511058234, 'reg_lambda': 3.8756641168055728, 'reg_alpha': 1.8789978831283782, 'min_child_samples': 37}. Best is trial 4 with value: -0.8419053911768698.
# [I 2025-11-16 23:35:34,307] Trial 6 finished with value: -0.84475532497879 and parameters: {'n_estimators': 500, 'learning_rate': 0.0835361075531176, 'num_leaves': 25, 'max_depth': 1, 'subsample': 0.6180909155642152, 'colsample_bytree': 0.7301321323053057, 'reg_lambda': 1.9433864484474102, 'reg_alpha': 0.5426980635477918, 'min_child_samples': 34}. Best is trial 4 with value: -0.8419053911768698.
# [I 2025-11-16 23:35:39,245] Trial 7 finished with value: -0.8676942831985999 and parameters: {'n_estimators': 400, 'learning_rate': 0.01909565280104538, 'num_leaves': 53, 'max_depth': 0, 'subsample': 0.9208787923016158, 'colsample_bytree': 0.6298202574719083, 'reg_lambda': 4.9344346830025865, 'reg_alpha': 1.5444895385933148, 'min_child_samples': 12}. Best is trial 4 with value: -0.8419053911768698.
# [I 2025-11-16 23:35:40,899] Trial 8 finished with value: -0.8816187016184021 and parameters: {'n_estimators': 300, 'learning_rate': 0.06538248584518043, 'num_leaves': 63, 'max_depth': 7, 'subsample': 0.9085081386743783, 'colsample_bytree': 0.6296178606936361, 'reg_lambda': 1.7923286427213632, 'reg_alpha': 0.23173811905025943, 'min_child_samples': 36}. Best is trial 4 with value: -0.8419053911768698.
# [I 2025-11-16 23:35:42,125] Trial 9 finished with value: -0.8420956280388886 and parameters: {'n_estimators': 600, 'learning_rate': 0.02142387495644906, 'num_leaves': 23, 'max_depth': 2, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'reg_lambda': 3.1877873567760657, 'reg_alpha': 1.774425485152653, 'min_child_samples': 21}. Best is trial 4 with value: -0.8419053911768698.
# [I 2025-11-16 23:35:46,088] Trial 10 finished with value: -0.8653720413816638 and parameters: {'n_estimators': 300, 'learning_rate': 0.010139048090380883, 'num_leaves': 38, 'max_depth': 10, 'subsample': 0.8144754354791038, 'colsample_bytree': 0.8429521169792498, 'reg_lambda': 0.07563407956692322, 'reg_alpha': 1.2271244390081462, 'min_child_samples': 6}. Best is trial 4 with value: -0.8419053911768698.
# [I 2025-11-16 23:35:47,783] Trial 11 finished with value: -0.8354010869753037 and parameters: {'n_estimators': 700, 'learning_rate': 0.014893502018773087, 'num_leaves': 41, 'max_depth': 3, 'subsample': 0.7737425087025644, 'colsample_bytree': 0.8920339412764792, 'reg_lambda': 3.428985852396359, 'reg_alpha': 1.2143685480664512, 'min_child_samples': 15}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:35:49,608] Trial 12 finished with value: -0.8363952072149985 and parameters: {'n_estimators': 700, 'learning_rate': 0.013934496079747987, 'num_leaves': 40, 'max_depth': 3, 'subsample': 0.8114637425678032, 'colsample_bytree': 0.9157908265277859, 'reg_lambda': 3.138214726279749, 'reg_alpha': 1.1457061612546722, 'min_child_samples': 16}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:35:51,207] Trial 13 finished with value: -0.8527391667411128 and parameters: {'n_estimators': 700, 'learning_rate': 0.03267555125994072, 'num_leaves': 40, 'max_depth': 3, 'subsample': 0.8134443425342889, 'colsample_bytree': 0.9364456838793964, 'reg_lambda': 3.3170321430599135, 'reg_alpha': 1.1203521409969806, 'min_child_samples': 17}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:35:53,121] Trial 14 finished with value: -0.838940118236102 and parameters: {'n_estimators': 700, 'learning_rate': 0.014418544077544065, 'num_leaves': 35, 'max_depth': 3, 'subsample': 0.8524337374155859, 'colsample_bytree': 0.9006453699263156, 'reg_lambda': 3.859788189773983, 'reg_alpha': 0.8434000383477445, 'min_child_samples': 7}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:00,953] Trial 15 finished with value: -0.9027935466991762 and parameters: {'n_estimators': 700, 'learning_rate': 0.04589551152503385, 'num_leaves': 44, 'max_depth': -1, 'subsample': 0.7610006806493648, 'colsample_bytree': 0.9930744627111218, 'reg_lambda': 2.9067190735691764, 'reg_alpha': 1.3410902852097726, 'min_child_samples': 28}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:02,207] Trial 16 finished with value: -0.8400248175447936 and parameters: {'n_estimators': 700, 'learning_rate': 0.015071375598458095, 'num_leaves': 32, 'max_depth': 2, 'subsample': 0.8642396983313831, 'colsample_bytree': 0.84078311583699, 'reg_lambda': 4.029919590532186, 'reg_alpha': 0.9359350874373904, 'min_child_samples': 19}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:04,236] Trial 17 finished with value: -0.857440301790055 and parameters: {'n_estimators': 600, 'learning_rate': 0.02730273608044661, 'num_leaves': 46, 'max_depth': 4, 'subsample': 0.7698391357205167, 'colsample_bytree': 0.9355980372732715, 'reg_lambda': 2.533881284358335, 'reg_alpha': 1.4344618947704235, 'min_child_samples': 16}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:05,258] Trial 18 finished with value: -0.8368681666998861 and parameters: {'n_estimators': 700, 'learning_rate': 0.02613263216022678, 'num_leaves': 30, 'max_depth': 2, 'subsample': 0.8661693590032661, 'colsample_bytree': 0.8624175337686145, 'reg_lambda': 1.277226349322531, 'reg_alpha': 0.7987382135397063, 'min_child_samples': 10}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:10,642] Trial 19 finished with value: -0.865518000138303 and parameters: {'n_estimators': 600, 'learning_rate': 0.015224187153092565, 'num_leaves': 73, 'max_depth': 9, 'subsample': 0.9646649714218306, 'colsample_bytree': 0.7898989834944574, 'reg_lambda': 4.367606606454754, 'reg_alpha': 1.0642249944887174, 'min_child_samples': 25}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:13,412] Trial 20 finished with value: -0.8481275811403002 and parameters: {'n_estimators': 700, 'learning_rate': 0.012116878299353814, 'num_leaves': 44, 'max_depth': 5, 'subsample': 0.9958550589220376, 'colsample_bytree': 0.9371260532218373, 'reg_lambda': 3.4904832000270054, 'reg_alpha': 0.023241923255106545, 'min_child_samples': 30}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:14,307] Trial 21 finished with value: -0.8385873985561754 and parameters: {'n_estimators': 700, 'learning_rate': 0.026349584958778927, 'num_leaves': 30, 'max_depth': 2, 'subsample': 0.8567059090507401, 'colsample_bytree': 0.8808303301386976, 'reg_lambda': 1.3177033196896877, 'reg_alpha': 0.7632988231956278, 'min_child_samples': 9}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:15,708] Trial 22 finished with value: -0.8395862329061623 and parameters: {'n_estimators': 700, 'learning_rate': 0.016761058090703166, 'num_leaves': 29, 'max_depth': 3, 'subsample': 0.7741742388806528, 'colsample_bytree': 0.8408796878055311, 'reg_lambda': 2.7531333819755965, 'reg_alpha': 0.5656960750349249, 'min_child_samples': 9}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:16,281] Trial 23 finished with value: -0.8510713520198386 and parameters: {'n_estimators': 600, 'learning_rate': 0.024990669275210944, 'num_leaves': 38, 'max_depth': 1, 'subsample': 0.8924602223574475, 'colsample_bytree': 0.8664246621696798, 'reg_lambda': 1.0817581363556492, 'reg_alpha': 1.239275263348628, 'min_child_samples': 13}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:17,155] Trial 24 finished with value: -0.8444915452695346 and parameters: {'n_estimators': 700, 'learning_rate': 0.04975141172284567, 'num_leaves': 47, 'max_depth': 1, 'subsample': 0.8264392134038689, 'colsample_bytree': 0.9143438695716055, 'reg_lambda': 1.8859625601033099, 'reg_alpha': 0.7468701695883843, 'min_child_samples': 18}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:18,382] Trial 25 finished with value: -0.8501425680478901 and parameters: {'n_estimators': 600, 'learning_rate': 0.03223842619684376, 'num_leaves': 34, 'max_depth': 3, 'subsample': 0.7459884541994417, 'colsample_bytree': 0.9669690740846307, 'reg_lambda': 2.2099304893500604, 'reg_alpha': 0.34934665523130637, 'min_child_samples': 10}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:20,406] Trial 26 finished with value: -0.8433274945237365 and parameters: {'n_estimators': 700, 'learning_rate': 0.012691579052779886, 'num_leaves': 28, 'max_depth': 4, 'subsample': 0.799638059302908, 'colsample_bytree': 0.8184898819243922, 'reg_lambda': 2.983157809036448, 'reg_alpha': 0.978071562790943, 'min_child_samples': 15}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:26,197] Trial 27 finished with value: -0.8725735194771701 and parameters: {'n_estimators': 500, 'learning_rate': 0.017195645577686967, 'num_leaves': 41, 'max_depth': -1, 'subsample': 0.8769465943924691, 'colsample_bytree': 0.8661360501108626, 'reg_lambda': 3.5819031110838595, 'reg_alpha': 1.1918613616451708, 'min_child_samples': 5}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:27,246] Trial 28 finished with value: -0.8387751514129043 and parameters: {'n_estimators': 700, 'learning_rate': 0.023073982700012978, 'num_leaves': 20, 'max_depth': 2, 'subsample': 0.9327072223971015, 'colsample_bytree': 0.761196880398442, 'reg_lambda': 1.4608985824284426, 'reg_alpha': 1.3652362398819995, 'min_child_samples': 20}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:30,456] Trial 29 finished with value: -0.8789009081719966 and parameters: {'n_estimators': 600, 'learning_rate': 0.02912620343116366, 'num_leaves': 55, 'max_depth': 6, 'subsample': 0.7903227674470005, 'colsample_bytree': 0.9558668147478308, 'reg_lambda': 0.5056928002801979, 'reg_alpha': 0.9169130476740412, 'min_child_samples': 23}. Best is trial 11 with value: -0.8354010869753037.
# [I 2025-11-16 23:36:30,461] A new study created in memory with name: no-name-15f0e938-9382-4157-9018-ed89b2f9158e
# 🔍 OPTIMIZING HORIZON t2
# [I 2025-11-16 23:36:32,122] Trial 0 finished with value: -1.005815990481158 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: -1.005815990481158.
# [I 2025-11-16 23:36:35,338] Trial 1 finished with value: -1.0044501498441674 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 1 with value: -1.0044501498441674.
# [I 2025-11-16 23:36:36,782] Trial 2 finished with value: -1.0151441380635404 and parameters: {'n_estimators': 150, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 0.5}. Best is trial 1 with value: -1.0044501498441674.
# [I 2025-11-16 23:36:37,523] Trial 3 finished with value: -1.0114347641369688 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 1 with value: -1.0044501498441674.
# [I 2025-11-16 23:36:40,838] Trial 4 finished with value: -1.0143460959582304 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.5}. Best is trial 1 with value: -1.0044501498441674.
# [I 2025-11-16 23:36:45,451] Trial 5 finished with value: -1.0037673920291628 and parameters: {'n_estimators': 350, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 5 with value: -1.0037673920291628.
# [I 2025-11-16 23:36:47,126] Trial 6 finished with value: -1.000387277587993 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 6 with value: -1.000387277587993.
# [I 2025-11-16 23:36:49,201] Trial 7 finished with value: -0.9988953402502538 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 0.5}. Best is trial 7 with value: -0.9988953402502538.
# [I 2025-11-16 23:36:50,250] Trial 8 finished with value: -1.0145254554427674 and parameters: {'n_estimators': 100, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 0.5}. Best is trial 7 with value: -0.9988953402502538.
# [I 2025-11-16 23:36:52,756] Trial 9 finished with value: -1.0081440955022 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': 0.5}. Best is trial 7 with value: -0.9988953402502538.
# [I 2025-11-16 23:36:54,846] Trial 10 finished with value: -1.0009242274991226 and parameters: {'n_estimators': 250, 'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.3}. Best is trial 7 with value: -0.9988953402502538.
# [I 2025-11-16 23:36:56,197] Trial 11 finished with value: -1.0010448074201244 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.3}. Best is trial 7 with value: -0.9988953402502538.
# [I 2025-11-16 23:36:57,612] Trial 12 finished with value: -0.9972161231739772 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:36:59,705] Trial 13 finished with value: -0.9976403154378843 and parameters: {'n_estimators': 150, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:02,829] Trial 14 finished with value: -0.9996385126008999 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:05,188] Trial 15 finished with value: -1.0034458812190903 and parameters: {'n_estimators': 250, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 0.3}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:07,297] Trial 16 finished with value: -1.0025650636895442 and parameters: {'n_estimators': 150, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:08,888] Trial 17 finished with value: -0.9972161231739772 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:09,750] Trial 18 finished with value: -1.0055933813498314 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:12,617] Trial 19 finished with value: -1.0011667332432976 and parameters: {'n_estimators': 300, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 0.3}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:15,694] Trial 20 finished with value: -1.0020895361826407 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:17,068] Trial 21 finished with value: -0.9972161231739772 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:18,373] Trial 22 finished with value: -0.9974992154088774 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:19,710] Trial 23 finished with value: -0.9972161231739772 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:21,868] Trial 24 finished with value: -0.9988657441654775 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:23,091] Trial 25 finished with value: -0.9993039360597435 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:24,996] Trial 26 finished with value: -0.9976403154378843 and parameters: {'n_estimators': 150, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 12 with value: -0.9972161231739772.
# [I 2025-11-16 23:37:26,341] Trial 27 finished with value: -0.9958183514695852 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': 0.5}. Best is trial 27 with value: -0.9958183514695852.
# [I 2025-11-16 23:37:28,400] Trial 28 finished with value: -1.0036544098880424 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 27 with value: -0.9958183514695852.
# [I 2025-11-16 23:37:30,383] Trial 29 finished with value: -1.003476439213416 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 0.3}. Best is trial 27 with value: -0.9958183514695852.
# [I 2025-11-16 23:37:30,386] A new study created in memory with name: no-name-43fdf75a-25d8-44e3-858e-c7cc729f74aa
# [I 2025-11-16 23:37:33,661] Trial 0 finished with value: -1.0874509067422715 and parameters: {'n_estimators': 300, 'learning_rate': 0.08927180304353628, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'reg_lambda': 1.5227525095137953, 'reg_alpha': 1.7323522915498704}. Best is trial 0 with value: -1.0874509067422715.
# [I 2025-11-16 23:37:34,484] Trial 1 finished with value: -1.0593432993983896 and parameters: {'n_estimators': 500, 'learning_rate': 0.051059032093947576, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'reg_lambda': 2.636424704863906, 'reg_alpha': 0.36680901970686763}. Best is trial 1 with value: -1.0593432993983896.
# [I 2025-11-16 23:37:36,069] Trial 2 finished with value: -1.0416676254094241 and parameters: {'n_estimators': 300, 'learning_rate': 0.03347776308515933, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8447411578889518, 'colsample_bytree': 0.6557975442608167, 'reg_lambda': 3.629301836816963, 'reg_alpha': 0.7327236865873834}. Best is trial 2 with value: -1.0416676254094241.
# [I 2025-11-16 23:37:37,618] Trial 3 finished with value: -1.0674118971692514 and parameters: {'n_estimators': 400, 'learning_rate': 0.06097839109531514, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.836965827544817, 'colsample_bytree': 0.6185801650879991, 'reg_lambda': 6.467903667112945, 'reg_alpha': 0.34104824737458306}. Best is trial 2 with value: -1.0416676254094241.
# [I 2025-11-16 23:37:40,492] Trial 4 finished with value: -1.084110996161644 and parameters: {'n_estimators': 200, 'learning_rate': 0.08889667907018929, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.7218455076693483, 'colsample_bytree': 0.6390688456025535, 'reg_lambda': 7.158097238609412, 'reg_alpha': 0.8803049874792026}. Best is trial 2 with value: -1.0416676254094241.
# [I 2025-11-16 23:37:40,943] Trial 5 finished with value: -0.9981096834410519 and parameters: {'n_estimators': 200, 'learning_rate': 0.03127353036780371, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.7035119926400067, 'colsample_bytree': 0.8650089137415928, 'reg_lambda': 3.8053996848046987, 'reg_alpha': 1.0401360423556216}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:47,684] Trial 6 finished with value: -1.0520529458301973 and parameters: {'n_estimators': 400, 'learning_rate': 0.015305744365500184, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.9757995766256756, 'colsample_bytree': 0.9579309401710595, 'reg_lambda': 6.381099809299767, 'reg_alpha': 1.8437484700462337}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:48,016] Trial 7 finished with value: -1.0061806799234332 and parameters: {'n_estimators': 200, 'learning_rate': 0.015703008378806716, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.7554709158757928, 'colsample_bytree': 0.7085396127095583, 'reg_lambda': 8.458637582367365, 'reg_alpha': 0.7135066533871786}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:48,557] Trial 8 finished with value: -1.0162557197863478 and parameters: {'n_estimators': 300, 'learning_rate': 0.03488960745139221, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.6298202574719083, 'colsample_bytree': 0.9947547746402069, 'reg_lambda': 7.9502029236699165, 'reg_alpha': 0.3974313630683448}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:51,358] Trial 9 finished with value: -1.0709302441926776 and parameters: {'n_estimators': 200, 'learning_rate': 0.06538248584518043, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.9085081386743783, 'colsample_bytree': 0.6296178606936361, 'reg_lambda': 4.226191556898454, 'reg_alpha': 0.23173811905025943}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:55,361] Trial 10 finished with value: -1.0199937423030287 and parameters: {'n_estimators': 600, 'learning_rate': 0.010139048090380883, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.7090747508804338, 'colsample_bytree': 0.876098829427658, 'reg_lambda': 9.637936713508779, 'reg_alpha': 1.3531447594855595}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:56,000] Trial 11 finished with value: -1.0070646905578147 and parameters: {'n_estimators': 200, 'learning_rate': 0.020228353231607526, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.7628905526894346, 'colsample_bytree': 0.7708980338870229, 'reg_lambda': 4.873723406553896, 'reg_alpha': 1.2390678862671982}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:56,429] Trial 12 finished with value: -1.0006553209078317 and parameters: {'n_estimators': 200, 'learning_rate': 0.02143717387163742, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.7835458343977252, 'colsample_bytree': 0.7853159707268006, 'reg_lambda': 9.948252090193968, 'reg_alpha': 0.7067922766539213}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:57,454] Trial 13 finished with value: -1.0125337409994808 and parameters: {'n_estimators': 300, 'learning_rate': 0.022571531235755515, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8056891692692755, 'colsample_bytree': 0.8560522696212751, 'reg_lambda': 9.99426194777396, 'reg_alpha': 1.1543590595691136}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:37:58,434] Trial 14 finished with value: -1.017832200912656 and parameters: {'n_estimators': 500, 'learning_rate': 0.023967031473697213, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6052561262871233, 'colsample_bytree': 0.795831954410391, 'reg_lambda': 3.0043932670435507, 'reg_alpha': 0.01595043990855438}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:38:00,413] Trial 15 finished with value: -1.049617746550312 and parameters: {'n_estimators': 200, 'learning_rate': 0.04479483394989504, 'max_depth': 6, 'min_child_weight': 2, 'subsample': 0.6874613708719653, 'colsample_bytree': 0.8681672195183853, 'reg_lambda': 5.000634646457255, 'reg_alpha': 1.5892907282241777}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:38:01,252] Trial 16 finished with value: -1.0256334322133993 and parameters: {'n_estimators': 300, 'learning_rate': 0.02808976183051849, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.7585197880317976, 'colsample_bytree': 0.743536173877238, 'reg_lambda': 1.0426610768778062, 'reg_alpha': 0.934939022741452}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:38:03,465] Trial 17 finished with value: -1.0246088131495692 and parameters: {'n_estimators': 400, 'learning_rate': 0.014339358262115584, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8714982728343171, 'colsample_bytree': 0.9186991893905657, 'reg_lambda': 5.830301166792237, 'reg_alpha': 0.5519339677336642}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:38:09,268] Trial 18 finished with value: -1.0686951233374917 and parameters: {'n_estimators': 500, 'learning_rate': 0.0422031924717065, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7999631989857672, 'colsample_bytree': 0.826853449737148, 'reg_lambda': 8.625996374911889, 'reg_alpha': 1.4454849621403116}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:38:09,765] Trial 19 finished with value: -0.9993932861775383 and parameters: {'n_estimators': 200, 'learning_rate': 0.018368359321537932, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6531827218643451, 'colsample_bytree': 0.9095972082022148, 'reg_lambda': 2.3067428796584872, 'reg_alpha': 1.1636604288408519}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:38:10,955] Trial 20 finished with value: -1.0045509921063887 and parameters: {'n_estimators': 400, 'learning_rate': 0.010136390254392036, 'max_depth': 4, 'min_child_weight': 7, 'subsample': 0.6509785970068126, 'colsample_bytree': 0.922899151269194, 'reg_lambda': 2.384208541925026, 'reg_alpha': 1.0851546410920725}. Best is trial 5 with value: -0.9981096834410519.
# [I 2025-11-16 23:38:11,325] Trial 21 finished with value: -0.9972603673905838 and parameters: {'n_estimators': 200, 'learning_rate': 0.019246873275243468, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.6950952224811027, 'colsample_bytree': 0.825892161012452, 'reg_lambda': 3.627016667829786, 'reg_alpha': 0.7953012630611171}. Best is trial 21 with value: -0.9972603673905838.
# ...
# [I 2025-11-16 23:47:37,520] Trial 21 finished with value: -1.0953615923458582 and parameters: {'n_estimators': 200, 'learning_rate': 0.016880757472171826, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.7422993282294453, 'colsample_bytree': 0.9153175069788861, 'reg_lambda': 7.924080244182423, 'reg_alpha': 1.220379719391075}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:38,064] Trial 22 finished with value: -1.095683370376219 and parameters: {'n_estimators': 200, 'learning_rate': 0.017401841479281203, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.7473595168337539, 'colsample_bytree': 0.910961118150516, 'reg_lambda': 8.37013322480733, 'reg_alpha': 1.5091219180561974}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:39,108] Trial 23 finished with value: -1.1009280220724398 and parameters: {'n_estimators': 300, 'learning_rate': 0.012481066916201789, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6636976461559223, 'colsample_bytree': 0.8387337848281731, 'reg_lambda': 7.093524597835943, 'reg_alpha': 0.6195857072107519}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:39,564] Trial 24 finished with value: -1.0981166623748 and parameters: {'n_estimators': 200, 'learning_rate': 0.024493136667161287, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.7881696660067136, 'colsample_bytree': 0.7840545195180846, 'reg_lambda': 9.594409621122466, 'reg_alpha': 0.9203078266160081}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:40,348] Trial 25 finished with value: -1.094256655635873 and parameters: {'n_estimators': 300, 'learning_rate': 0.012721414228005655, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.6696207993900746, 'colsample_bytree': 0.900435300392965, 'reg_lambda': 5.585470402670109, 'reg_alpha': 1.1751877294165454}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:41,562] Trial 26 finished with value: -1.1045019037558752 and parameters: {'n_estimators': 300, 'learning_rate': 0.012489304907178794, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.6687840829785424, 'colsample_bytree': 0.9036007400787756, 'reg_lambda': 5.397964003063562, 'reg_alpha': 1.1745094757118257}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:43,690] Trial 27 finished with value: -1.1111286829447564 and parameters: {'n_estimators': 300, 'learning_rate': 0.01350119352657395, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6368081022394957, 'colsample_bytree': 0.9535899680056209, 'reg_lambda': 5.0579669960566624, 'reg_alpha': 1.4994435918905769}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:44,374] Trial 28 finished with value: -1.1302862907467444 and parameters: {'n_estimators': 300, 'learning_rate': 0.042112080599835656, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.6907939095057634, 'colsample_bytree': 0.996391065514728, 'reg_lambda': 5.879158303478468, 'reg_alpha': 1.3289985293927689}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:46,822] Trial 29 finished with value: -1.1245400982538056 and parameters: {'n_estimators': 200, 'learning_rate': 0.01795888902828745, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.6435145850989601, 'colsample_bytree': 0.8912101550266425, 'reg_lambda': 2.483435830357906, 'reg_alpha': 1.6531010988894512}. Best is trial 7 with value: -1.0939468404845782.
# [I 2025-11-16 23:47:46,824] A new study created in memory with name: no-name-26df19c7-b43b-4c52-9759-e0aebfd920a5
# [I 2025-11-16 23:47:48,452] Trial 0 finished with value: -1.182252933240648 and parameters: {'n_estimators': 400, 'learning_rate': 0.08927180304353628, 'num_leaves': 64, 'max_depth': 6, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'reg_lambda': 0.2904180608409973, 'reg_alpha': 1.7323522915498704, 'min_child_samples': 26}. Best is trial 0 with value: -1.182252933240648.
# [I 2025-11-16 23:47:53,019] Trial 1 finished with value: -1.1354920974495504 and parameters: {'n_estimators': 600, 'learning_rate': 0.010485387725194618, 'num_leaves': 79, 'max_depth': 8, 'subsample': 0.6849356442713105, 'colsample_bytree': 0.6727299868828402, 'reg_lambda': 0.9170225492671691, 'reg_alpha': 0.6084844859190754, 'min_child_samples': 23}. Best is trial 1 with value: -1.1354920974495504.
# [I 2025-11-16 23:47:59,109] Trial 2 finished with value: -1.1551171533837281 and parameters: {'n_estimators': 500, 'learning_rate': 0.019553708662745254, 'num_leaves': 57, 'max_depth': 0, 'subsample': 0.7168578594140873, 'colsample_bytree': 0.7465447373174767, 'reg_lambda': 2.28034992108518, 'reg_alpha': 1.5703519227860272, 'min_child_samples': 12}. Best is trial 1 with value: -1.1354920974495504.
# [I 2025-11-16 23:48:00,862] Trial 3 finished with value: -1.1608570369853526 and parameters: {'n_estimators': 500, 'learning_rate': 0.03912141628549695, 'num_leaves': 22, 'max_depth': 6, 'subsample': 0.6682096494749166, 'colsample_bytree': 0.6260206371941118, 'reg_lambda': 4.7444276862666666, 'reg_alpha': 1.9312640661491187, 'min_child_samples': 34}. Best is trial 1 with value: -1.1354920974495504.
# [I 2025-11-16 23:48:02,213] Trial 4 finished with value: -1.1287744629896301 and parameters: {'n_estimators': 400, 'learning_rate': 0.012521954287060391, 'num_leaves': 61, 'max_depth': 4, 'subsample': 0.6488152939379115, 'colsample_bytree': 0.798070764044508, 'reg_lambda': 0.17194260557609198, 'reg_alpha': 1.8186408041575641, 'min_child_samples': 14}. Best is trial 4 with value: -1.1287744629896301.
# [I 2025-11-16 23:48:04,163] Trial 5 finished with value: -1.13846870574111 and parameters: {'n_estimators': 600, 'learning_rate': 0.020497980520950188, 'num_leaves': 51, 'max_depth': 5, 'subsample': 0.6739417822102108, 'colsample_bytree': 0.9878338511058234, 'reg_lambda': 3.8756641168055728, 'reg_alpha': 1.8789978831283782, 'min_child_samples': 37}. Best is trial 4 with value: -1.1287744629896301.
# [I 2025-11-16 23:48:04,505] Trial 6 finished with value: -1.0885695196378653 and parameters: {'n_estimators': 500, 'learning_rate': 0.0835361075531176, 'num_leaves': 25, 'max_depth': 1, 'subsample': 0.6180909155642152, 'colsample_bytree': 0.7301321323053057, 'reg_lambda': 1.9433864484474102, 'reg_alpha': 0.5426980635477918, 'min_child_samples': 34}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:09,621] Trial 7 finished with value: -1.1473780096723638 and parameters: {'n_estimators': 400, 'learning_rate': 0.01909565280104538, 'num_leaves': 53, 'max_depth': 0, 'subsample': 0.9208787923016158, 'colsample_bytree': 0.6298202574719083, 'reg_lambda': 4.9344346830025865, 'reg_alpha': 1.5444895385933148, 'min_child_samples': 12}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:10,993] Trial 8 finished with value: -1.1618911628539759 and parameters: {'n_estimators': 300, 'learning_rate': 0.06538248584518043, 'num_leaves': 63, 'max_depth': 7, 'subsample': 0.9085081386743783, 'colsample_bytree': 0.6296178606936361, 'reg_lambda': 1.7923286427213632, 'reg_alpha': 0.23173811905025943, 'min_child_samples': 36}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:11,815] Trial 9 finished with value: -1.1055800927981043 and parameters: {'n_estimators': 600, 'learning_rate': 0.02142387495644906, 'num_leaves': 23, 'max_depth': 2, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'reg_lambda': 3.1877873567760657, 'reg_alpha': 1.774425485152653, 'min_child_samples': 21}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:16,715] Trial 10 finished with value: -1.1871084390530697 and parameters: {'n_estimators': 700, 'learning_rate': 0.048865984661301265, 'num_leaves': 35, 'max_depth': 10, 'subsample': 0.8262452362725613, 'colsample_bytree': 0.7447070264153981, 'reg_lambda': 1.3384134435618573, 'reg_alpha': 0.7849057842052648, 'min_child_samples': 31}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:17,650] Trial 11 finished with value: -1.106860153579896 and parameters: {'n_estimators': 600, 'learning_rate': 0.029532611412973843, 'num_leaves': 20, 'max_depth': 2, 'subsample': 0.7737425087025644, 'colsample_bytree': 0.9207839224242349, 'reg_lambda': 3.1775419665315305, 'reg_alpha': 1.2143685480664512, 'min_child_samples': 20}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:18,728] Trial 12 finished with value: -1.1226768498223336 and parameters: {'n_estimators': 700, 'learning_rate': 0.028671877697077793, 'num_leaves': 34, 'max_depth': 2, 'subsample': 0.7735338046637228, 'colsample_bytree': 0.8734031212891499, 'reg_lambda': 3.138214726279749, 'reg_alpha': 0.06717176986894446, 'min_child_samples': 6}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:19,681] Trial 13 finished with value: -1.1555110381294573 and parameters: {'n_estimators': 600, 'learning_rate': 0.0958679253682185, 'num_leaves': 35, 'max_depth': 2, 'subsample': 0.6035573012408144, 'colsample_bytree': 0.8638091044560918, 'reg_lambda': 2.777459525821401, 'reg_alpha': 0.49998372145609044, 'min_child_samples': 28}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:23,546] Trial 14 finished with value: -1.1889596878275397 and parameters: {'n_estimators': 500, 'learning_rate': 0.0577243738263282, 'num_leaves': 28, 'max_depth': -1, 'subsample': 0.9931586479472261, 'colsample_bytree': 0.8049323200200472, 'reg_lambda': 3.7415994891075077, 'reg_alpha': 1.059962685602378, 'min_child_samples': 18}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:24,905] Trial 15 finished with value: -1.126544472802577 and parameters: {'n_estimators': 700, 'learning_rate': 0.015603395817192167, 'num_leaves': 28, 'max_depth': 3, 'subsample': 0.6114993625916325, 'colsample_bytree': 0.9639185471806767, 'reg_lambda': 2.1242642563158944, 'reg_alpha': 1.3410902852097726, 'min_child_samples': 40}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:25,211] Trial 16 finished with value: -1.0887736214728059 and parameters: {'n_estimators': 300, 'learning_rate': 0.034271154352431034, 'num_leaves': 45, 'max_depth': 1, 'subsample': 0.7311941285873849, 'colsample_bytree': 0.736465650805349, 'reg_lambda': 4.061370589243337, 'reg_alpha': 0.8220246253270658, 'min_child_samples': 25}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:28,034] Trial 17 finished with value: -1.1847617447138157 and parameters: {'n_estimators': 300, 'learning_rate': 0.07240286376561743, 'num_leaves': 45, 'max_depth': 0, 'subsample': 0.8505915654206465, 'colsample_bytree': 0.7214675553651019, 'reg_lambda': 4.0699685278891575, 'reg_alpha': 0.692576493891873, 'min_child_samples': 30}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:30,981] Trial 18 finished with value: -1.1671319279927215 and parameters: {'n_estimators': 300, 'learning_rate': 0.040016441734128376, 'num_leaves': 42, 'max_depth': -1, 'subsample': 0.7471371041060483, 'colsample_bytree': 0.8005828061689466, 'reg_lambda': 1.5397387039154533, 'reg_alpha': 0.32825413066328835, 'min_child_samples': 25}. Best is trial 6 with value: -1.0885695196378653.
# [I 2025-11-16 23:48:31,290] Trial 19 finished with value: -1.0862409805453 and parameters: {'n_estimators': 400, 'learning_rate': 0.043991456924415084, 'num_leaves': 73, 'max_depth': 1, 'subsample': 0.7080887077215605, 'colsample_bytree': 0.7093005494078926, 'reg_lambda': 4.412618761561294, 'reg_alpha': 0.9073210715005743, 'min_child_samples': 32}. Best is trial 19 with value: -1.0862409805453.
# [I 2025-11-16 23:48:32,310] Trial 20 finished with value: -1.1551592246223783 and parameters: {'n_estimators': 400, 'learning_rate': 0.05431747219090299, 'num_leaves': 80, 'max_depth': 4, 'subsample': 0.629247743591745, 'colsample_bytree': 0.6960313971494949, 'reg_lambda': 0.8830196500242824, 'reg_alpha': 1.010598318308754, 'min_child_samples': 33}. Best is trial 19 with value: -1.0862409805453.
# [I 2025-11-16 23:48:32,590] Trial 21 finished with value: -1.0899928528359948 and parameters: {'n_estimators': 300, 'learning_rate': 0.03708241162392901, 'num_leaves': 73, 'max_depth': 1, 'subsample': 0.7160209385977362, 'colsample_bytree': 0.7684380641318647, 'reg_lambda': 4.498977733223972, 'reg_alpha': 0.8500273678334441, 'min_child_samples': 40}. Best is trial 19 with value: -1.0862409805453.
# [I 2025-11-16 23:48:32,917] Trial 22 finished with value: -1.087992407418249 and parameters: {'n_estimators': 400, 'learning_rate': 0.026829180473191154, 'num_leaves': 44, 'max_depth': 1, 'subsample': 0.6991179872309533, 'colsample_bytree': 0.7016057439201218, 'reg_lambda': 4.29146031280716, 'reg_alpha': 0.4810639793459217, 'min_child_samples': 28}. Best is trial 19 with value: -1.0862409805453.
# [I 2025-11-16 23:48:33,857] Trial 23 finished with value: -1.1298418506840253 and parameters: {'n_estimators': 500, 'learning_rate': 0.025494227892730804, 'num_leaves': 69, 'max_depth': 3, 'subsample': 0.7037562828392268, 'colsample_bytree': 0.6950691894741341, 'reg_lambda': 4.476319780570322, 'reg_alpha': 0.4971813227542326, 'min_child_samples': 30}. Best is trial 19 with value: -1.0862409805453.
# [I 2025-11-16 23:48:34,214] Trial 24 finished with value: -1.0861171985909828 and parameters: {'n_estimators': 400, 'learning_rate': 0.04577507412223409, 'num_leaves': 43, 'max_depth': 1, 'subsample': 0.6423295599960299, 'colsample_bytree': 0.6692075216044164, 'reg_lambda': 2.609094118697648, 'reg_alpha': 0.32897608950596813, 'min_child_samples': 35}. Best is trial 24 with value: -1.0861171985909828.
# [I 2025-11-16 23:48:34,969] Trial 25 finished with value: -1.1415636579368234 and parameters: {'n_estimators': 400, 'learning_rate': 0.04622630560246233, 'num_leaves': 41, 'max_depth': 3, 'subsample': 0.7760975920640389, 'colsample_bytree': 0.6005734951329541, 'reg_lambda': 3.4807910285676877, 'reg_alpha': 0.34934665523130637, 'min_child_samples': 37}. Best is trial 24 with value: -1.0861171985909828.
# [I 2025-11-16 23:48:38,855] Trial 26 finished with value: -1.178420217735974 and parameters: {'n_estimators': 400, 'learning_rate': 0.04319336225744759, 'num_leaves': 49, 'max_depth': -1, 'subsample': 0.6420993579215434, 'colsample_bytree': 0.6691871121301782, 'reg_lambda': 2.653278416823283, 'reg_alpha': 0.050657190557805265, 'min_child_samples': 28}. Best is trial 24 with value: -1.0861171985909828.
# [I 2025-11-16 23:48:39,194] Trial 27 finished with value: -1.0891889893001556 and parameters: {'n_estimators': 400, 'learning_rate': 0.025137376271024924, 'num_leaves': 57, 'max_depth': 1, 'subsample': 0.6856379646288024, 'colsample_bytree': 0.7014907237438908, 'reg_lambda': 4.320803275501946, 'reg_alpha': 0.2862610150096251, 'min_child_samples': 32}. Best is trial 24 with value: -1.0861171985909828.
# [I 2025-11-16 23:48:43,271] Trial 28 finished with value: -1.172748310888322 and parameters: {'n_estimators': 400, 'learning_rate': 0.03387397129159173, 'num_leaves': 42, 'max_depth': 0, 'subsample': 0.7472876731026725, 'colsample_bytree': 0.7753120949683062, 'reg_lambda': 3.612141963269819, 'reg_alpha': 0.17423172249979588, 'min_child_samples': 28}. Best is trial 24 with value: -1.0861171985909828.
# [I 2025-11-16 23:48:45,671] Trial 29 finished with value: -1.165719643413253 and parameters: {'n_estimators': 500, 'learning_rate': 0.05241571122531831, 'num_leaves': 69, 'max_depth': 5, 'subsample': 0.8138015736454048, 'colsample_bytree': 0.6513018967415438, 'reg_lambda': 2.912493416550591, 'reg_alpha': 0.40518244839095097, 'min_child_samples': 35}. Best is trial 24 with value: -1.0861171985909828.
#  Hyperparameter tuning complete.

# %%
def evaluate_metrics(y_true, y_pred, base_pers, base_climo):
    RMSE = rmse(y_true, y_pred)
    return {
        "RMSE": RMSE,
        "MAE": mean_absolute_error(y_true, y_pred),
        "R2": r2_score(y_true, y_pred),
        "Skill_vs_Persistence": 1 - RMSE / base_pers,
        "Skill_vs_Climatology": 1 - RMSE / base_climo
    }

model_choice = {
    "t1": "lgbm", "t2": "lgbm", "t3": "lgbm",
    "t4": "xgb", "t5": "rf"
}

final_models = {}
results = []

for h in horizons:
    print(f"\n🔧 FINAL TRAINING — Horizon {h}")

    Xtr_h = X_train_sel_dict[h]
    Xte_h = X_test_sel_dict[h]

    y_train_h = y_train_dict[h]
    y_test_h  = y_test_dict[h]

    choice = model_choice[h]

    if choice == "lgbm":
        model = LGBMRegressor(**lgbm_best_params[h])
    elif choice == "xgb":
        model = XGBRegressor(**xgb_best_params[h])
    else:
        model = RandomForestRegressor(**rf_best_params[h])

    model.fit(Xtr_h, y_train_h)
    y_pred_test = model.predict(Xte_h)


    final_models[h] = model

    base = baseline_metrics[h]
    met = evaluate_metrics(y_test_h, y_pred_test,
                           base["RMSE_persistence"],
                           base["RMSE_climatology"])

    results.append({"Horizon": h, "ModelType": choice.upper(), **met})

results_df = pd.DataFrame(results)
print("\n📊 Final Test Results (t1..t5):")
display(results_df.round(4))
# Out:
# 🔧 FINAL TRAINING — Horizon t1
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6246
# [LightGBM] [Info] Number of data points in the train set: 3098, number of used features: 25
# [LightGBM] [Info] Start training from score 28.412072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# 🔧 FINAL TRAINING — Horizon t2
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000523 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6501
# [LightGBM] [Info] Number of data points in the train set: 3098, number of used features: 26
# [LightGBM] [Info] Start training from score 28.412137
#
# 🔧 FINAL TRAINING — Horizon t3
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000537 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6252
# [LightGBM] [Info] Number of data points in the train set: 3098, number of used features: 26
# [LightGBM] [Info] Start training from score 28.412427
#
# 🔧 FINAL TRAINING — Horizon t4
#
# 🔧 FINAL TRAINING — Horizon t5
#
# 📊 Final Test Results (t1..t5):
#   Horizon ModelType    RMSE     MAE      R2  Skill_vs_Persistence  \
# 0      t1      LGBM  0.8162  0.6499  0.6810                0.0318
# 1      t2      LGBM  0.9836  0.7956  0.5367                0.1135
# 2      t3      LGBM  1.0314  0.8357  0.4904                0.1576
# 3      t4       XGB  1.0492  0.8522  0.4723                0.1758
# 4      t5        RF  1.0672  0.8653  0.4534                0.1577
#
#    Skill_vs_Climatology
# 0                0.4517
# 1                0.3393
# 2                0.3069
# 3                0.2946
# 4                0.2817
